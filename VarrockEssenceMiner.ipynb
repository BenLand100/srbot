# %%
# %matplotlib inline
from IPython.display import clear_output
from pytesseract import image_to_string

from srbot import *

# %%
#Aubury essence miner varrock

mm_dirt_road = [111,104,104]
mm_bank_floor = [92,86,86]

travel_icon = load_image('travel_icon.png')
magic_icon = load_image('magic_shop.png')
teleport = load_image('teleport.png')

aubury = True

target()
total_trips = 0
last_mine = mark_time()
logins = 0
while True:
    client = get_client()
    if len(find_bitmap(loginscreen,client)) > 0:
        logins = logins + 1
        if logins > 10:
            raise RuntimeError('Too many logins! Bailing out before we get fishy!')
        login()
        continue
    if mark_time()-last_mine > 10*60:
        raise RuntimeError('Bailing out, wandered around for 10 minutes, definitely lost.')
        
    minimap = get_minimap()
    black = find_colors([0,0,0],minimap,tol=0.05)
    inv = count_inv()
    print('black',len(black))
    if len(black) > 2000: #in mine
        border = filter_far(black,[[mmxc-mmxs,mmyc-mmys]],40)
        if len(border) > 9000: #we're in a wing
            if inv == 28: #full, leave
                mainscreen = get_mainscreen()
                portal = find_colors([215,212,174],mainscreen,tol=0.08,mode='hsl')
                if len(portal) > 0:
                    np.random.shuffle(portal)
                    click_mouse(*(portal[0]+[msxs,msys]))
                    flag_wait()
                    continue
                else:
                    print('no portal!')
                    travel = find_best_bitmap(travel_icon,minimap,mode='xcorr',tol=0.15)
                    print(len(travel))
                    if len(travel) > 0:
                        np.random.shuffle(travel)
                        click_mouse(*(travel[0]+[mmxs,mmys]))
                        flag_wait()
                        continue
            else: #mine
                if len(find_bitmap(flag,minimap)) > 0:
                    click_mouse(mmxc,mmyc)
                    flag_wait()
                did_something = False
                points = np.asarray([np.random.randint(msxs,msxs+msw,15),np.random.randint(msys,msys+msh,15)]).T
                if confirm_click(points):
                    did_something = True
                    flag_wait()
                    i = 0
                    while True:
                        new_inv = count_inv()
                        if new_inv != inv:
                            i = 0
                            inv = new_inv
                        if inv == 28:
                            break
                        if i > 10:
                            break
                        i += 1
                        sleep(0.5)
                if did_something:
                    last_mine = mark_time()
                    continue
            
            print('trying new area...')
            area = find_colors([200,200,200],minimap,mode='hsl',tol=0.3)
            area = filter_radius(area,[mmxc-mmxs,mmyc-mmys],70)
            area = filter_far(area,black,15)
            if len(area) > 0:
                np.random.shuffle(area)
                click_mouse(*(area[0]+[mmxs,mmys]))
                flag_wait()
            else:
                print('hopelessly lost')
        else:
            print('moving to essence')
            area = find_colors([200,200,200],minimap,mode='hsl',tol=0.3)
            area = filter_radius(area,[mmxc-mmxs,mmyc-mmys],65)
            if len(area) > 0:
                points = area[np.argsort(-area[:,0]-area[:,1])]
                points = points[:max(int(len(points)/5),1)]
                np.random.shuffle(points)
                click_mouse(*(points[0]+[mmxs,mmys]))
                sleep(3.0)
            else:
                print('hopelessly lost')
                    
    elif aubury: # in varrock
        road = find_colors(mm_dirt_road,minimap,tol=(0.05,0.05,0.05),mode='hsl')
        road = filter_radius(road,[mmxc-mmxs,mmyc-mmys],65)
        print('road',len(road))
        if inv == 28: #go bank
            bank_floor = find_colors(mm_bank_floor,minimap,mode='hsl',tol=(0.06,0.05,0.05))
            npcs = find_colors([238,238,0],minimap,mode='hsl',tol=0.1)
            clusters,counts = cluster(npcs,radius=4)
            print('bank_clusters',counts)
            if len(counts) > 0 and np.max(counts) > 30:
                bank_points = clusters[np.argmax(counts)]
                bank_points = filter_near(npcs,bank_points,4)-[0,10]
                print('bank',len(bank_points))
                if len(bank_points) > 5:
                    np.random.shuffle(bank_points)
                    click_mouse(*(bank_points[0]+[mmxs,mmys]))
                    flag_wait(imax=200)
                    mainscreen = get_mainscreen()
                    a = find_colors([80,60,8],mainscreen,mode='hsl',tol=0.1)
                    b = find_colors([157,141,110],mainscreen,mode='hsl',tol=0.1)
                    points = filter_near(a,b,40)
                    np.random.shuffle(points)
                    if len(points) > 1:
                        minidx = np.argmin(np.sum(np.square(points-[msxc-msxs,msyc-msys]),axis=1))
                        points[-1],points[minidx] = points[minidx],points[-1]
                    for point in points[-5:]:
                        click_mouse(*point,left=False)
                        sleep(0.05)
                        use = find_bitmap(use_booth,get_mainscreen())
                        if len(use) > 0:
                            click_mouse(*(use[0]+[10,10]))
                            flag_wait()
                            sleep(2.0)
                            deposit_all()
                            click_mouse(488,43)
                            sleep(1.0)
                            run_on()
                            if np.random.random() < 0.2:
                                polish_minimap()
                            clear_output()
                            break
                        move_mouse(*(point+[0,-25]))
                    continue
            print('heading north')
            walkto = road[np.argmin(road[:,1]+road[:,0])]
        else: #go aubury
            magic = find_best_bitmap(magic_icon,minimap,mode='xcorr',tol=0.2)
            print('magic icons',len(magic))
            if len(magic) > 0:
                np.random.shuffle(magic)
                click_mouse(*(magic[0]+[mmxs+5,mmys+5]))
                flag_wait()
                print('search for aubury')
                for i in range(20):
                    mainscreen = get_mainscreen()
                    a = find_colors([79,72,35],mainscreen,tol=(0.05,0.1,0.1),mode='hsl')
                    b = find_colors([145,105,35],mainscreen,tol=(0.05,0.1,0.1),mode='hsl')
                    auburypts = filter_near(a,b,30)
                    if len(auburypts) > 0:
                        np.random.shuffle(auburypts)
                        move_mouse(*(auburypts[0]+[msxs,msys]))
                        sleep(0.05)
                        uptext = get_uptext()
                        yellow = find_colors([238,238,0],uptext,mode='hsl',tol=0.18)
                        if len(yellow) > 100:
                            click_mouse(*(auburypts[0]+[msxs,msys]),left=False)
                            mainscreen = get_mainscreen()
                            clickme = find_bitmap(teleport,mainscreen)
                            if len(clickme) == 1:
                                click_mouse(*(clickme[0]+[msxs+15,msys+3]))
                                sleep(5.0)
                                break
                continue
            print('heading south')
            walkto = road[np.argmax(road[:,1]+0.25*road[:,0])]
        click_mouse(*(walkto+[mmxs,mmys]))
        sleep(1.0)
    else: #wizard's guild
        pass
# Out:
# black 465
# road 2634
# magic icons 1
# search for aubury
# black 481
# road 1606
# magic icons 0
# heading south
# black 481
# road 2243
# magic icons 1
# search for aubury
# black 465
# road 4007
# magic icons 1
# search for aubury
# black 481
# road 3638
# magic icons 1
# search for aubury
# black 480
# road 3652
# magic icons 1
# search for aubury
# black 481
# road 3614
# magic icons 1
# search for aubury
# black 481
# road 3614
# magic icons 1
# search for aubury
# black 481
# road 3579
# magic icons 1
# search for aubury
# black 481
# road 3708
# magic icons 1
# search for aubury
# black 481
# road 3690
# magic icons 1
# search for aubury
# black 481
# road 3688
# magic icons 1
# search for aubury
# black 481
# road 3660
# magic icons 1
# search for aubury
# black 481
# road 3722
# magic icons 1
# search for aubury
# black 481
# road 3735
# magic icons 1
# search for aubury
# black 481
# road 3745
# magic icons 1
# search for aubury
# black 481
# road 3775
# magic icons 1
# search for aubury
# black 481
# road 3779
# magic icons 1
# search for aubury
# black 481
# road 3819
# magic icons 1
# search for aubury
# black 481
# road 3812
# magic icons 1
# search for aubury
# black 481
# road 3824
# magic icons 1
# search for aubury
# black 481
# road 3837
# magic icons 1
# search for aubury
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-a93bd278eb53> in <module>
#      23         continue
#      24     if mark_time()-last_mine > 10*60:
# ---> 25         raise RuntimeError('Bailing out, wandered around for 10 minutes, definitely lost.')
#      26
#      27     minimap = get_minimap()
#
# RuntimeError: Bailing out, wandered around for 10 minutes, definitely lost.
